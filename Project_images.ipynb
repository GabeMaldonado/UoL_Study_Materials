# %% [markdown]
# <a href="https://colab.research.google.com/github/GabeMaldonado/UoL_Study_Materials/blob/main/Project_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image

Image(filename='/content/Screen Shot 2022-03-23 at 11.42.33 AM.png')

# %%
Image(filename='/content/Screen Shot 2022-03-23 at 11.34.51 AM.png')

# %%
Image(filename='/content/Screen Shot 2022-03-23 at 11.58.40 AM.png')

# %%
Image(filename='/content/Screen Shot 2022-03-23 at 1.11.51 PM.png')

# %%
Image(filename='/content/Screen Shot 2022-03-23 at 1.58.07 PM.png')

# %%
Image(filename='/content/Screen Shot 2022-03-23 at 2.26.08 PM.png')

# %%
Image(filename='/content/Screen Shot 2022-03-23 at 3.39.57 PM.png')

# %%
Image(filename='/content/Screen Shot 2022-03-23 at 3.45.11 PM.png')
